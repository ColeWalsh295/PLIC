# %%
import numpy as np
import pandas as pd

# %%
def SetMajor(df):
    df['Q6b'] = df['Q6b_y'].fillna(df['Q6b_x'])
    df['Q6b.i'] = df['Q6b.i_y'].fillna(df['Q6b.i_x'])
    
    conditions = [
        df['Q6b'] < 4,
        df['Q6b.i'] < 5
    ]
    
    output = [
        'Physics', 'Non-physics'
    ]
    
    df['Major'] = np.select(conditions, output, None)
    return df

def SetGender(df):
    conditions = [
        df['Q6e_1_y'] == 1,
        df['Q6e_2_y'] == 1,
        df['Q6e_1_x'] == 1,
        df['Q6e_2_x'] == 1
    ]

    output = [
        'Male', 'Female'
    ]

    df['Gender'] = np.select(conditions, np.tile(output, 2), None)
    return df

def SetURM(df):
    conditions = [
        df['Q6f_5_y'] == 1,
        df['Q6f_1_y'] == 1,
        df['Q6f_7_y'] == 1,
        df['Q6f_3_y'] == 1,
        df['Q6f_4_y'] == 1,
        df['Q6f_2_y'] == 1,
        df['Q6f_6_y'] == 1,    
        df['Q6f_5_x'] == 1,
        df['Q6f_1_x'] == 1,
        df['Q6f_7_x'] == 1,
        df['Q6f_3_x'] == 1,
        df['Q6f_4_x'] == 1,
        df['Q6f_2_x'] == 1,
        df['Q6f_6_x'] == 1,
    ]

    output = ['URM'] * 5 + ['Majority'] * 2

    df['URM_Status'] = np.select(conditions, np.tile(output, 2), None) 
    return df

def SetClassStanding(df):
    conditions = [
        df['Q6a_y'] == 1,
        df['Q6a_y'] > 1,
        df['Q6a_x'] == 1,
        df['Q6a_x'] > 1,
    ]

    output = ['Freshman', 'Beyond-first-year']

    df['Class_Standing'] = np.select(conditions, np.tile(output, 2), None) 
    return df

# %%
df = pd.read_csv('Collective_Surveys/Complete/Complete_Concat_CourseInfo.csv')

df = SetMajor(df)
df = SetGender(df)
df = SetURM(df)
df = SetClassStanding(df)
# cols = [c for c in df.columns if 'Q1' in c or 'Q2' in c or 'Q3' in c or 'Q4' in c] + ['Major', 'Gender', 'URM_Status', 
#                                                                                       'Class_Standing', 'Survey_x', 'Survey_y',
#                                                                                       'Class_ID', 'Course_Level', 
#                                                                                       'PreScores', 'PostScores']
# df = df[cols]
# Out:
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (17,18,33,34,39,40,65,66,67,68,97,98,101,125,126,135,136,141,142,167,168,171,172,203,204,205,217,218,239,240,241,249,269,270,305,306,311,312,313,323,349,350,351,353,355,357,361,365,385,386,405,406,413,414,419,537,545,547,549,551) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df['Matched'] = df[['Survey_x', 'Survey_y']].transform(lambda x: pd.notnull(x['Survey_x']) * pd.notnull(x['Survey_y']), axis = 1)
df['N_Matched'] = df.groupby('Class_ID')['Matched'].transform(np.sum)

df['PreOnly'] = df[['Survey_x', 'Survey_y']].transform(lambda x: pd.notnull(x['Survey_x']) * pd.isnull(x['Survey_y']), axis = 1)
df['N_PreOnly'] = df.groupby('Class_ID')['PreOnly'].transform(np.sum)

df['PostOnly'] = df[['Survey_x', 'Survey_y']].transform(lambda x: pd.isnull(x['Survey_x']) * pd.notnull(x['Survey_y']), axis = 1)
df['N_PostOnly'] = df.groupby('Class_ID')['PostOnly'].transform(np.sum)

df['Download_Available'] = df[['N_PreOnly', 'N_PostOnly', 'N_Matched']].transform(lambda x: (x['N_PreOnly'] != 1) * 
                                                                                  (x['N_PostOnly'] != 1) * 
                                                                                  (x['N_Matched'] != 1), axis = 1)

df['Matched_Available'] = df['N_Matched'] > 1
df['Valid_Available'] = (df['N_PreOnly'] + df['N_Matched'] != 1) & (df['N_PostOnly'] + df['N_Matched'] != 1)
df = df.drop(columns = ['PreOnly', 'PostOnly', 'Matched', 'N_PreOnly', 'N_PostOnly', 'N_Matched'])

df_preOnly = df.loc[pd.notnull(df['Survey_x']) & pd.isnull(df['Survey_y']), :]
df_postOnly = df.loc[pd.isnull(df['Survey_x']) & pd.notnull(df['Survey_y']), :]
df_matchOnly = df.loc[pd.notnull(df['Survey_x']) & pd.notnull(df['Survey_y']), :]

len(df_preOnly) + len(df_postOnly) + len(df_matchOnly) == len(df)
# Out:
# True

# %%
def CrossTab(df):
    df_tab = df.loc[:, ['Class_ID', 'Gender', 'URM_Status', 'Major', 'Class_Standing']]

    tab = pd.crosstab(df_tab['Class_ID'], [df_tab['Gender'], df_tab['URM_Status'], df_tab['Major'], df_tab['Class_Standing']])
    tab['Class_Standing_Available'] = [False if 1 in row else True for row in tab.values.tolist()]
    tab['Major_Available'] = [False if 1 in row else True for row in tab.values.tolist()]
    tab['URM_Available'] = [False if 1 in row else True for row in tab.values.tolist()]
    tab['Gender_Available'] = [False if 1 in row else True for row in tab.values.tolist()]

    for ID, Row in tab.iterrows():
        if((Row['Class_Standing_Available'] * Row['Major_Available'] * Row['URM_Available'] * 
            Row['Gender_Available']).values[0]):
            continue
        if(not Row['Class_Standing_Available'].values[0]):
            df_class = df_tab.loc[df['Class_ID'] == ID, :]
            tab_class = pd.crosstab(df_class['Gender'], [df_class['URM_Status'], df_class['Major']])
            if(1 not in tab_class.values):
                tab.loc[ID, ['Major_Available', 'URM_Available', 'Gender_Available']] = True
                continue
        if(not Row['Major_Available'].values[0]):
            df_class = df_tab.loc[df['Class_ID'] == ID, :]
            tab_class = pd.crosstab(df_class['Gender'], [df_class['URM_Status'], df_class['Class_Standing']])
            if(1 not in tab_class.values):
                tab.loc[ID, ['Class_Standing_Available', 'URM_Available', 'Gender_Available']] = True
                continue
        if(not Row['URM_Available'].values[0]):
            df_class = df_tab.loc[df['Class_ID'] == ID, :]
            tab_class = pd.crosstab(df_class['Gender'], [df_class['Major'], df_class['Class_Standing']])
            if(1 not in tab_class.values):
                tab.loc[ID, ['Class_Standing_Available', 'Major_Available', 'Gender_Available']] = True
                continue
        elif(not Row['Gender_Available'].values[0]):
            df_class = df_tab.loc[df['Class_ID'] == ID, :]
            tab_class = pd.crosstab(df_class['URM_Status'], [df_class['Major_Status'], df_class['Class_Standing']])
            if(1 not in tab_class.values):
                tab.loc[ID, ['Class_Standing_Available', 'Major_Available', 'URM_Available']] = True
                continue
        if((not Row['Class_Standing_Available'].values[0]) * (not Row['Major_Available'].values[0])):
            df_class = df_tab.loc[df['Class_ID'] == ID, :]
            tab_class = pd.crosstab(df_class['Gender'], df_class['URM_Status'])
            if(1 not in tab_class.values):
                tab.loc[ID, ['URM_Available', 'Gender_Available']] = True
                continue
        if((not Row['Class_Standing_Available'].values[0]) * (not Row['URM_Available'].values[0])):
            df_class = df_tab.loc[df['Class_ID'] == ID, :]
            tab_class = pd.crosstab(df_class['Gender'], df_class['Major'])
            if(1 not in tab_class.values):
                tab.loc[ID, ['Major_Available', 'Gender_Available']] = True
                continue
        elif((not Row['Class_Standing_Available'].values[0]) * (not Row['Gender_Available'].values[0])):
            df_class = df_tab.loc[df['Class_ID'] == ID, :]
            tab_class = pd.crosstab(df_class['URM_Status'], df_class['Major'])
            if(1 not in tab_class.values):
                tab.loc[ID, ['Major_Available', 'URM_Available']] = True
                continue
        if((not Row['Major_Available'].values[0]) * (not Row['URM_Available'].values[0])):
            df_class = df_tab.loc[df['Class_ID'] == ID, :]
            tab_class = pd.crosstab(df_class['Gender'], df_class['Class_Standing'])
            if(1 not in tab_class.values):
                tab.loc[ID, ['Class_Standing_Available', 'Gender_Available']] = True
                continue
        if((not Row['Major_Available'].values[0]) * (not Row['Gender_Available'].values[0])):
            df_class = df_tab.loc[df['Class_ID'] == ID, :]
            tab_class = pd.crosstab(df_class['URM_Status'], df_class['Class_Standing'])
            if(1 not in tab_class.values):
                tab.loc[ID, ['Class_Standing_Available', 'URM_Available']] = True
                continue
        if((not Row['URM_Available'].values[0]) * (not Row['Gender_Available'].values[0])):
            df_class = df_tab.loc[df['Class_ID'] == ID, :]
            tab_class = pd.crosstab(df_class['Major'], df_class['Class_Standing'])
            if(1 not in tab_class.values):
                tab.loc[ID, ['Class_Standing_Available', 'Major_Available']] = True
                continue
        if((not Row['Class_Standing_Available'].values[0]) * (not Row['Major_Available'].values[0]) * 
             (not Row['URM_Available'].values[0])):
            df_class = df_tab.loc[df['Class_ID'] == ID, :]
            if(1 not in df_class['Gender'].value_counts().values):
                tab.loc[ID, 'Gender_Available'] = True
                continue
        if((not Row['Class_Standing_Available'].values[0]) * (not Row['Major_Available'].values[0]) * 
             (not Row['Gender_Available'].values[0])):
            df_class = df_tab.loc[df['Class_ID'] == ID, :]
            if(1 not in df_class['URM_Status'].value_counts().values):
                tab.loc[ID, 'URM_Available'] = True
                continue
        if((not Row['Class_Standing_Available'].values[0]) * (not Row['URM_Available'].values[0]) * 
             (not Row['Gender_Available'].values[0])):
            df_class = df_tab.loc[df['Class_ID'] == ID, :]
            if(1 not in df_class['Major'].value_counts().values):
                tab.loc[ID, 'Major_Available'] = True
                continue
        if((not Row['Major_Available'].values[0]) * (not Row['URM_Available'].values[0]) * 
             (not Row['Gender_Available'].values[0])):
            df_class = df_tab.loc[df['Class_ID'] == ID, :]
            if(1 not in df_class['Class_Standing'].value_counts().values):
                tab.loc[ID, 'Class_Standing_Available'] = True
                continue

    tab = tab[['Class_Standing_Available', 'Major_Available', 'URM_Available', 'Gender_Available']].reset_index()
    tab.columns = tab.columns.droplevel(level = [1, 2,3])
    df_out = df.merge(tab, how = 'left', on = 'Class_ID')
    return(df_out)

# %%
df_preOnlyTab = CrossTab(df_preOnly)
df_postOnlyTab = CrossTab(df_postOnly)
df_matchTab = CrossTab(df_matchOnly)
df_Tab = pd.concat([df_preOnlyTab, df_postOnlyTab, df_matchTab], axis = 0, join = 'outer').reset_index(drop = True)

df_Tab['Gender_Available_Download'] = (df_Tab.groupby('Class_ID')['Gender_Available'].transform('nunique') == 1) & \
(df_Tab['Gender_Available'] == True)
df_Tab['URM_Available_Download'] = (df_Tab.groupby('Class_ID')['URM_Available'].transform('nunique') == 1) & \
(df_Tab['URM_Available'] == True)
df_Tab['Major_Available_Download'] = (df_Tab.groupby('Class_ID')['Major_Available'].transform('nunique') == 1) & \
(df_Tab['Major_Available'] == True)
df_Tab['Class_Standing_Available_Download'] = (df_Tab.groupby('Class_ID')['Class_Standing_Available'].transform('nunique') == 1) & \
(df_Tab['Class_Standing_Available'] == True)

df_Tab = df_Tab.drop(columns = ['Gender_Available', 'URM_Available', 'Major_Available', 'Class_Standing_Available'])

# %%
def CountValues(df):

    df_Tab = pd.crosstab(df['Class_ID'], df['Gender'])
    df_Tab['Gender_Available'] = [False if 1 in v else True for v in df_Tab.values.tolist()]

    df_Tab_dummy = pd.crosstab(df['Class_ID'], df['URM_Status'])
    df_Tab_dummy['URM_Available'] = [False if 1 in v else True for v in df_Tab_dummy.values.tolist()]
    df_Tab = df_Tab.merge(df_Tab_dummy, how = 'left', on = 'Class_ID')

    df_Tab_dummy = pd.crosstab(df['Class_ID'], df['Major'])
    df_Tab_dummy['Major_Available'] = [False if 1 in v else True for v in df_Tab_dummy.values.tolist()]
    df_Tab = df_Tab.merge(df_Tab_dummy, how = 'left', on = 'Class_ID')

    df_Tab_dummy = pd.crosstab(df['Class_ID'], df['Class_Standing'])
    df_Tab_dummy['Class_Standing_Available'] = [False if 1 in v else True for v in df_Tab_dummy.values.tolist()]
    df_Tab = df_Tab.merge(df_Tab_dummy, how = 'left', on = 'Class_ID')

    print(df_Tab)
    df_Tab = df_Tab[['Gender_Available', 'URM_Available', 'Major_Available', 'Class_Standing_Available']].reset_index()
    return df_Tab

# %%
df_pre = df_Tab.loc[pd.notnull(df_Tab['Survey_x']), :]
df_Final = df_Tab.merge(CountValues(df_pre), how ='left', 
                        on = 'Class_ID').rename(columns = {'Gender_Available':'Gender_Available_Pre', 
                                                           'URM_Available':'URM_Available_Pre',
                                                           'Major_Available':'Major_Available_Pre',
                                                           'Class_Standing_Available':'Class_Standing_Available_Pre'})

df_post = df_Tab.loc[pd.notnull(df_Tab['Survey_y']), :]
df_Final = df_Final.merge(CountValues(df_post), how ='left',
                        on = 'Class_ID').rename(columns = {'Gender_Available':'Gender_Available_Post', 
                                                           'URM_Available':'URM_Available_Post',
                                                           'Major_Available':'Major_Available_Post',
                                                           'Class_Standing_Available':'Class_Standing_Available_Post'})

df_Final = df_Final.merge(CountValues(df_matchOnly), how ='left',
                        on = 'Class_ID').rename(columns = {'Gender_Available':'Gender_Available_Match', 
                                                           'URM_Available':'URM_Available_Match',
                                                           'Major_Available':'Major_Available_Match',
                                                           'Class_Standing_Available':'Class_Standing_Available_Match'})

df_Final['Gender_Available_Valid'] = df_Final['Gender_Available_Pre'].fillna(True) & df_Final['Gender_Available_Post'].fillna(True)
df_Final['URM_Available_Valid'] = df_Final['URM_Available_Pre'].fillna(True) & df_Final['URM_Available_Post'].fillna(True)
df_Final['Major_Available_Valid'] = df_Final['Major_Available_Pre'].fillna(True) & df_Final['Major_Available_Post'].fillna(True)
df_Final['Class_Standing_Available_Valid'] = df_Final['Class_Standing_Available_Pre'].fillna(True) & df_Final['Class_Standing_Available_Post'].fillna(True)
df_Final = df_Final.drop(columns = ['Gender_Available_Pre', 'Gender_Available_Post', 'URM_Available_Pre', 'URM_Available_Post', 
                                    'Major_Available_Pre', 'Major_Available_Post', 'Class_Standing_Available_Pre', 
                                    'Class_Standing_Available_Post'])
# Out:
#                    Female  Male  Gender_Available  Majority  URM  \
# Class_ID
# R_12QFe4VQPh6oNW1       5    15              True        16    4
# R_12t10i0liTKxQuH      12    15              True        13   14
# R_1DA4MjYI6kJcpRW       4    19              True        20    3
# R_1E6g9AAGCZcNC4z       7    10              True        15    1
# R_1IB300CxBKh0Tw7      28    62              True        72   16
# R_1LHvn3R5Afj8eUc      70    46              True        87   24
# R_1Lv8h75V2mtHdj7       3    17              True        19    1
# R_1Oko8BpPfb9rt0G      18    79              True        87    9
# R_1PRvAep4UEZKmoi       3    14              True        12    5
# R_1QDH836nn3XsCEC       3    13              True        15    1
# R_1dHrngC5fnItWQj       1    17             False        18    0
# R_1eRcOhZpre7mhcC      35    54              True        69   15
# R_1gU9RGAQf2fpKPq       1     9             False         5    5
# R_1gubfNoIBBmw0wZ       6    13              True        18    0
# R_1ifcZfwB09mFFt0      28    32              True        48   13
# R_1ih5Iehl2ArglT2     130   101              True       163   63
# R_1jB7mHGYxH4Hgi8       5    15              True        16    5
# R_1n7wUeClpEuZOkp      16     0              True        10    8
# R_1nTRv0WikH05GGN       0     4              True         4    0
# R_1oBXVOVbXJ6mbd8       3     7              True         8    3
# R_1pJNmdyl9Z2lXit       4     9              True         6    7
# R_1reT6Pvd9hZsljf       5    14              True        11    8
# R_1riVAun30VkuYam       1     4             False         2    2
# R_21hYdjinjp0k6Dw       1     8             False         3    6
# R_22ufgL2VQq1l4Ft      62   158              True       194   22
# R_24q0K2G7CvLBC90       1     9             False         8    2
# R_27BAp1dY9KUURf1      28    26              True        50    1
# R_2DTys2sMNEPNUas      46    73              True        93   22
# R_2E3I53tWJ18Yrh1      12    26              True        33    4
# R_2R8MnTyv2jFgPzA      13    30              True        37    5
# ...                   ...   ...               ...       ...  ...
# R_306JBsevlEJwO73       4     3              True         6    1
# R_3383bqp4hOSfVs6       4    16              True        22    0
# R_33C0JO3MvPhUjg0       0     1             False         0    1
# R_33svFR3Dzit5gMP      41    94              True       127    9
# R_3DvXkKcsXGosQmN       9    10              True        15    4
# R_3EfD4kQOcRIqPd1      44    42              True        77    9
# R_3FLrT3FNDbu41vG       0     7              True         5    2
# R_3Jx6pTC9zYp0JjN      50    37              True        77    9
# R_3KIXxDs5O6DnoMq      61   209              True       238   27
# R_3PFfsO3XVxfcdbo      11    29              True        36    3
# R_3QYRWvIUGTgTHLA      36    21              True        54    5
# R_3fNprNmbwV9C4X0      66    68              True       111   16
# R_3ijRcPfXo8MUfFj     113    99              True       174   33
# R_3kNzLJWZjV68mK7       3    16              True        15    3
# R_3saWqGdBUCbYgRG       2     5              True         5    0
# R_5vSHC3dAv5Rtvm9       3    14              True        11    7
# R_6VuzaPTgCFmgEmJ       2    19              True        21    2
# R_6rq9bCkfvLDJEdz      51    58              True        87   12
# R_AbnDTWVllhcHtN7      79    39              True        99   18
# R_DnPBuVnC0UjmC1b      35    86              True       102   17
# R_QaHsOagJRfOPuet       1     2             False         1    2
# R_RKRNIWFu1gZuSPf     195   150              True       232  103
# R_Rls0GV6AMQeGWid       1    11             False        12    2
# R_eDQgZq5IOwNJ0SB      37   107              True       135   13
# R_poaCzravLe9WtQl       3     6              True         4    5
# R_sRwOfzbp6ufaWU9       8     6              True         8    6
# R_ur0ff9OTvW0jB1D       3     7              True         7    3
# R_yvBX55C72Ye8W1b      37    76              True       100   11
# R_zYlbzTtLmdvnpPb      43    32              True        61   12
# R_zfk080BHz6RWixb     101    86              True       147   34
#
#                    URM_Available  Non-physics  Physics  Major_Available  \
# Class_ID
# R_12QFe4VQPh6oNW1           True            3       17             True
# R_12t10i0liTKxQuH           True           27        0             True
# R_1DA4MjYI6kJcpRW           True            0       23             True
# R_1E6g9AAGCZcNC4z          False           12        5             True
# R_1IB300CxBKh0Tw7           True           31       57             True
# R_1LHvn3R5Afj8eUc           True          114        2             True
# R_1Lv8h75V2mtHdj7          False            0       20             True
# R_1Oko8BpPfb9rt0G           True           31       63             True
# R_1PRvAep4UEZKmoi           True            4       13             True
# R_1QDH836nn3XsCEC          False            2       14             True
# R_1dHrngC5fnItWQj           True            0       18             True
# R_1eRcOhZpre7mhcC           True           86        2             True
# R_1gU9RGAQf2fpKPq           True            2        8             True
# R_1gubfNoIBBmw0wZ           True            0       19             True
# R_1ifcZfwB09mFFt0           True           50        9             True
# R_1ih5Iehl2ArglT2           True          217       12             True
# R_1jB7mHGYxH4Hgi8           True            0       23             True
# R_1n7wUeClpEuZOkp           True           16        2             True
# R_1nTRv0WikH05GGN           True            1        3            False
# R_1oBXVOVbXJ6mbd8           True            5        6             True
# R_1pJNmdyl9Z2lXit           True            4        9             True
# R_1reT6Pvd9hZsljf           True           10        9             True
# R_1riVAun30VkuYam           True            0        5             True
# R_21hYdjinjp0k6Dw           True            7        2             True
# R_22ufgL2VQq1l4Ft           True          216        2             True
# R_24q0K2G7CvLBC90           True            0       10             True
# R_27BAp1dY9KUURf1          False           47        6             True
# R_2DTys2sMNEPNUas           True          108       10             True
# R_2E3I53tWJ18Yrh1           True            1       39            False
# R_2R8MnTyv2jFgPzA           True           18       24             True
# ...                          ...          ...      ...              ...
# R_306JBsevlEJwO73          False            6        1            False
# R_3383bqp4hOSfVs6           True            1       20            False
# R_33C0JO3MvPhUjg0          False            0        1            False
# R_33svFR3Dzit5gMP           True          130        7             True
# R_3DvXkKcsXGosQmN           True           11       10             True
# R_3EfD4kQOcRIqPd1           True           60       24             True
# R_3FLrT3FNDbu41vG           True            4        3             True
# R_3Jx6pTC9zYp0JjN           True           87        1            False
# R_3KIXxDs5O6DnoMq           True          260        1            False
# R_3PFfsO3XVxfcdbo           True            6       34             True
# R_3QYRWvIUGTgTHLA           True           56        3             True
# R_3fNprNmbwV9C4X0           True          111       14             True
# R_3ijRcPfXo8MUfFj           True          207        5             True
# R_3kNzLJWZjV68mK7           True            0       20             True
# R_3saWqGdBUCbYgRG           True            1        6            False
# R_5vSHC3dAv5Rtvm9           True            6       10             True
# R_6VuzaPTgCFmgEmJ           True            2       21             True
# R_6rq9bCkfvLDJEdz           True           66       25             True
# R_AbnDTWVllhcHtN7           True          116        0             True
# R_DnPBuVnC0UjmC1b           True          115        7             True
# R_QaHsOagJRfOPuet          False            0        3             True
# R_RKRNIWFu1gZuSPf           True          329       12             True
# R_Rls0GV6AMQeGWid           True            0       14             True
# R_eDQgZq5IOwNJ0SB           True          136       14             True
# R_poaCzravLe9WtQl           True            0        9             True
# R_sRwOfzbp6ufaWU9           True           14        0             True
# R_ur0ff9OTvW0jB1D           True            0       10             True
# R_yvBX55C72Ye8W1b           True          108        6             True
# R_zYlbzTtLmdvnpPb           True           73        1            False
# R_zfk080BHz6RWixb           True          184        2             True
#
#                    Beyond-first-year  Freshman  Class_Standing_Available
# Class_ID
# R_12QFe4VQPh6oNW1                 15         5                      True
# R_12t10i0liTKxQuH                 27         0                      True
# R_1DA4MjYI6kJcpRW                 23         0                      True
# R_1E6g9AAGCZcNC4z                  5        12                      True
# R_1IB300CxBKh0Tw7                  5        86                      True
# R_1LHvn3R5Afj8eUc                 10       107                      True
# R_1Lv8h75V2mtHdj7                 20         0                      True
# R_1Oko8BpPfb9rt0G                  4        93                      True
# R_1PRvAep4UEZKmoi                 15         2                      True
# R_1QDH836nn3XsCEC                 16         0                      True
# R_1dHrngC5fnItWQj                 17         1                     False
# R_1eRcOhZpre7mhcC                 81         8                      True
# R_1gU9RGAQf2fpKPq                 10         0                      True
# R_1gubfNoIBBmw0wZ                 19         0                      True
# R_1ifcZfwB09mFFt0                 34        27                      True
# R_1ih5Iehl2ArglT2                209        24                      True
# R_1jB7mHGYxH4Hgi8                 23         0                      True
# R_1n7wUeClpEuZOkp                 19         0                      True
# R_1nTRv0WikH05GGN                  4         0                      True
# R_1oBXVOVbXJ6mbd8                  1        10                     False
# R_1pJNmdyl9Z2lXit                 13         0                      True
# R_1reT6Pvd9hZsljf                 15         4                      True
# R_1riVAun30VkuYam                  5         0                      True
# R_21hYdjinjp0k6Dw                  7         3                      True
# R_22ufgL2VQq1l4Ft                221         0                      True
# R_24q0K2G7CvLBC90                 10         0                      True
# R_27BAp1dY9KUURf1                 50         6                      True
# R_2DTys2sMNEPNUas                117         2                      True
# R_2E3I53tWJ18Yrh1                 40         0                      True
# R_2R8MnTyv2jFgPzA                  3        41                      True
# ...                              ...       ...                       ...
# R_306JBsevlEJwO73                  4         2                      True
# R_3383bqp4hOSfVs6                 23         0                      True
# R_33C0JO3MvPhUjg0                  1         0                     False
# R_33svFR3Dzit5gMP                 29       109                      True
# R_3DvXkKcsXGosQmN                 21         0                      True
# R_3EfD4kQOcRIqPd1                 66        20                      True
# R_3FLrT3FNDbu41vG                  7         0                      True
# R_3Jx6pTC9zYp0JjN                 86         2                      True
# R_3KIXxDs5O6DnoMq                267         5                      True
# R_3PFfsO3XVxfcdbo                 39         1                     False
# R_3QYRWvIUGTgTHLA                 59         1                     False
# R_3fNprNmbwV9C4X0                 62        72                      True
# R_3ijRcPfXo8MUfFj                 61       154                      True
# R_3kNzLJWZjV68mK7                 20         0                      True
# R_3saWqGdBUCbYgRG                  7         0                      True
# R_5vSHC3dAv5Rtvm9                  6        12                      True
# R_6VuzaPTgCFmgEmJ                 23         0                      True
# R_6rq9bCkfvLDJEdz                 27        90                      True
# R_AbnDTWVllhcHtN7                113         6                      True
# R_DnPBuVnC0UjmC1b                 27        96                      True
# R_QaHsOagJRfOPuet                  3         0                      True
# R_RKRNIWFu1gZuSPf                 17       335                      True
# R_Rls0GV6AMQeGWid                 14         0                      True
# R_eDQgZq5IOwNJ0SB                 49       102                      True
# R_poaCzravLe9WtQl                  9         0                      True
# R_sRwOfzbp6ufaWU9                 14         0                      True
# R_ur0ff9OTvW0jB1D                 10         0                      True
# R_yvBX55C72Ye8W1b                112         3                      True
# R_zYlbzTtLmdvnpPb                 75         0                      True
# R_zfk080BHz6RWixb                184         6                      True
#
# [76 rows x 12 columns]
#                    Female  Male  Gender_Available  Majority  URM  \
# Class_ID
# R_12QFe4VQPh6oNW1       3     4              True         6    1
# R_12t10i0liTKxQuH      28    24              True        25   27
# R_1DA4MjYI6kJcpRW       5    18              True        21    2
# R_1E6g9AAGCZcNC4z       2     2              True         4    0
# R_1IB300CxBKh0Tw7      24    54              True        64   12
# R_1LHvn3R5Afj8eUc      52    36              True        66   20
# R_1Lv8h75V2mtHdj7       2    11              True        13    0
# R_1OMRnfQCygrVfk1      41   108              True       138    8
# R_1Oko8BpPfb9rt0G      15    75              True        81    8
# R_1PRvAep4UEZKmoi       1    14             False        11    3
# R_1QDH836nn3XsCEC       1    23             False        22    2
# R_1dHrngC5fnItWQj       1    13             False        14    0
# R_1eRcOhZpre7mhcC      19    25              True        38    5
# R_1gU9RGAQf2fpKPq       1     8             False         5    4
# R_1gubfNoIBBmw0wZ       5     9              True        14    0
# R_1ifcZfwB09mFFt0       1     4             False         5    0
# R_1ih5Iehl2ArglT2     117   107              True       170   50
# R_1jB7mHGYxH4Hgi8       2    11              True        12    2
# R_1n7wUeClpEuZOkp      13     0              True         7    8
# R_1nTRv0WikH05GGN       1     6             False         6    0
# R_1oBXVOVbXJ6mbd8       5     5              True         7    4
# R_1pJNmdyl9Z2lXit       4    13              True         9    7
# R_1qfctSUrYxBOtgG       8    12              True        18    2
# R_1reT6Pvd9hZsljf       5    12              True        10    7
# R_1riVAun30VkuYam       2     1             False         0    2
# R_22ufgL2VQq1l4Ft      56   148              True       179   21
# R_24q0K2G7CvLBC90       1     3             False         4    0
# R_27BAp1dY9KUURf1       5     5              True         8    1
# R_2ANjv44absxxVo5      18    58              True        68    7
# R_2DTys2sMNEPNUas      42    60              True        84   14
# ...                   ...   ...               ...       ...  ...
# R_3Jx6pTC9zYp0JjN       0     6              True         5    0
# R_3KIXxDs5O6DnoMq      38   149              True       165   20
# R_3PFfsO3XVxfcdbo       8    22              True        28    2
# R_3QYRWvIUGTgTHLA      31    13              True        41    5
# R_3VITrHFM2bFAxdD       1     8             False         4    5
# R_3fNprNmbwV9C4X0      70    74              True       117   18
# R_3iLp9MKT4i6bz77      97    97              True       146   40
# R_3ijRcPfXo8MUfFj     104    93              True       162   31
# R_3kNzLJWZjV68mK7       2     6              True         7    1
# R_3qyQ3LSxFo7dCWh       1     9             False         7    2
# R_5vSHC3dAv5Rtvm9       0     4              True         2    2
# R_6VuzaPTgCFmgEmJ       2    13              True        14    2
# R_6rq9bCkfvLDJEdz      32    35              True        55    6
# R_8kyCQSyJlUBfQgp       0     1             False         1    0
# R_8wvNlB4VyPgMOit      75    61              True       102   29
# R_AbnDTWVllhcHtN7      44    21              True        53   10
# R_DnPBuVnC0UjmC1b      26    67              True        72   21
# R_QaHsOagJRfOPuet       0     2              True         1    1
# R_RKRNIWFu1gZuSPf     176   115              True       202   82
# R_ULcwzs6p5Nw6hb3       3     4              True         6    0
# R_djaSlPZqvyU0OYh      96    73              True       126   32
# R_eDQgZq5IOwNJ0SB      25    62              True        82    7
# R_poaCzravLe9WtQl       3     2              True         2    3
# R_rj41VGCbwbO1zHP       3     1             False         4    0
# R_sRwOfzbp6ufaWU9       6     3              True         4    4
# R_suiryM1wMLx8Prr      12     0              True         9    4
# R_ur0ff9OTvW0jB1D       2     3              True         4    1
# R_yvBX55C72Ye8W1b      38    66              True        95    7
# R_zYlbzTtLmdvnpPb      23    13              True        29    7
# R_zfk080BHz6RWixb      96    73              True       135   28
#
#                    URM_Available  Non-physics  Physics  Major_Available  \
# Class_ID
# R_12QFe4VQPh6oNW1          False            1        6            False
# R_12t10i0liTKxQuH           True           52        0             True
# R_1DA4MjYI6kJcpRW           True            0       23             True
# R_1E6g9AAGCZcNC4z           True            3        1            False
# R_1IB300CxBKh0Tw7           True           25       50             True
# R_1LHvn3R5Afj8eUc           True           86        2             True
# R_1Lv8h75V2mtHdj7           True            0       13             True
# R_1OMRnfQCygrVfk1           True          138       12             True
# R_1Oko8BpPfb9rt0G           True           28       59             True
# R_1PRvAep4UEZKmoi           True            1       14            False
# R_1QDH836nn3XsCEC           True            2       23             True
# R_1dHrngC5fnItWQj           True            0       14             True
# R_1eRcOhZpre7mhcC           True           44        1            False
# R_1gU9RGAQf2fpKPq           True            2        7             True
# R_1gubfNoIBBmw0wZ           True            0       14             True
# R_1ifcZfwB09mFFt0           True            4        1            False
# R_1ih5Iehl2ArglT2           True          210       11             True
# R_1jB7mHGYxH4Hgi8           True            0       14             True
# R_1n7wUeClpEuZOkp           True           12        2             True
# R_1nTRv0WikH05GGN           True            1        6            False
# R_1oBXVOVbXJ6mbd8           True            6        5             True
# R_1pJNmdyl9Z2lXit           True            4       13             True
# R_1qfctSUrYxBOtgG           True            2       19             True
# R_1reT6Pvd9hZsljf           True           10        7             True
# R_1riVAun30VkuYam           True            0        3             True
# R_22ufgL2VQq1l4Ft           True          200        2             True
# R_24q0K2G7CvLBC90           True            0        4             True
# R_27BAp1dY9KUURf1          False            8        2             True
# R_2ANjv44absxxVo5           True           69        8             True
# R_2DTys2sMNEPNUas           True           94        8             True
# ...                          ...          ...      ...              ...
# R_3Jx6pTC9zYp0JjN           True            5        0             True
# R_3KIXxDs5O6DnoMq           True          180        1            False
# R_3PFfsO3XVxfcdbo           True            3       27             True
# R_3QYRWvIUGTgTHLA           True           44        2             True
# R_3VITrHFM2bFAxdD           True            1        8            False
# R_3fNprNmbwV9C4X0           True          122       13             True
# R_3iLp9MKT4i6bz77           True          165       22             True
# R_3ijRcPfXo8MUfFj           True          192        5             True
# R_3kNzLJWZjV68mK7          False            0        8             True
# R_3qyQ3LSxFo7dCWh           True            0       10             True
# R_5vSHC3dAv5Rtvm9           True            1        3            False
# R_6VuzaPTgCFmgEmJ           True            1       15            False
# R_6rq9bCkfvLDJEdz           True           44       19             True
# R_8kyCQSyJlUBfQgp          False            0        1            False
# R_8wvNlB4VyPgMOit           True          132        1            False
# R_AbnDTWVllhcHtN7           True           65        0             True
# R_DnPBuVnC0UjmC1b           True           88        4             True
# R_QaHsOagJRfOPuet          False            0        2             True
# R_RKRNIWFu1gZuSPf           True          277       12             True
# R_ULcwzs6p5Nw6hb3           True            1        6            False
# R_djaSlPZqvyU0OYh           True          158        4             True
# R_eDQgZq5IOwNJ0SB           True           82        6             True
# R_poaCzravLe9WtQl           True            0        5             True
# R_rj41VGCbwbO1zHP           True            3        0             True
# R_sRwOfzbp6ufaWU9           True            9        0             True
# R_suiryM1wMLx8Prr           True            8        5             True
# R_ur0ff9OTvW0jB1D          False            0        5             True
# R_yvBX55C72Ye8W1b           True           98        5             True
# R_zYlbzTtLmdvnpPb           True           36        0             True
# R_zfk080BHz6RWixb           True          163        4             True
#
#                    Beyond-first-year  Freshman  Class_Standing_Available
# Class_ID
# R_12QFe4VQPh6oNW1                  6         1                     False
# R_12t10i0liTKxQuH                 52         0                      True
# R_1DA4MjYI6kJcpRW                 23         0                      True
# R_1E6g9AAGCZcNC4z                  0         4                      True
# R_1IB300CxBKh0Tw7                  3        76                      True
# R_1LHvn3R5Afj8eUc                  6        82                      True
# R_1Lv8h75V2mtHdj7                 13         0                      True
# R_1OMRnfQCygrVfk1                 42       109                      True
# R_1Oko8BpPfb9rt0G                  2        88                      True
# R_1PRvAep4UEZKmoi                 15         0                      True
# R_1QDH836nn3XsCEC                 25         0                      True
# R_1dHrngC5fnItWQj                 13         1                     False
# R_1eRcOhZpre7mhcC                 40         5                      True
# R_1gU9RGAQf2fpKPq                  9         0                      True
# R_1gubfNoIBBmw0wZ                 14         0                      True
# R_1ifcZfwB09mFFt0                  1         4                     False
# R_1ih5Iehl2ArglT2                203        23                      True
# R_1jB7mHGYxH4Hgi8                 14         0                      True
# R_1n7wUeClpEuZOkp                 15         0                      True
# R_1nTRv0WikH05GGN                  7         0                      True
# R_1oBXVOVbXJ6mbd8                  1        10                     False
# R_1pJNmdyl9Z2lXit                 17         0                      True
# R_1qfctSUrYxBOtgG                 19         2                      True
# R_1reT6Pvd9hZsljf                 13         4                      True
# R_1riVAun30VkuYam                  3         0                      True
# R_22ufgL2VQq1l4Ft                205         0                      True
# R_24q0K2G7CvLBC90                  4         0                      True
# R_27BAp1dY9KUURf1                 10         0                      True
# R_2ANjv44absxxVo5                 21        58                      True
# R_2DTys2sMNEPNUas                101         1                     False
# ...                              ...       ...                       ...
# R_3Jx6pTC9zYp0JjN                  6         0                      True
# R_3KIXxDs5O6DnoMq                184         4                      True
# R_3PFfsO3XVxfcdbo                 29         1                     False
# R_3QYRWvIUGTgTHLA                 45         1                     False
# R_3VITrHFM2bFAxdD                  9         0                      True
# R_3fNprNmbwV9C4X0                 61        84                      True
# R_3iLp9MKT4i6bz77                 71       123                      True
# R_3ijRcPfXo8MUfFj                 48       151                      True
# R_3kNzLJWZjV68mK7                  7         0                      True
# R_3qyQ3LSxFo7dCWh                 10         0                      True
# R_5vSHC3dAv5Rtvm9                  1         3                     False
# R_6VuzaPTgCFmgEmJ                 16         0                      True
# R_6rq9bCkfvLDJEdz                  2        70                      True
# R_8kyCQSyJlUBfQgp                  0         1                     False
# R_8wvNlB4VyPgMOit                128        12                      True
# R_AbnDTWVllhcHtN7                 65         0                      True
# R_DnPBuVnC0UjmC1b                 18        76                      True
# R_QaHsOagJRfOPuet                  2         0                      True
# R_RKRNIWFu1gZuSPf                 13       284                      True
# R_ULcwzs6p5Nw6hb3                  6         1                     False
# R_djaSlPZqvyU0OYh                171         0                      True
# R_eDQgZq5IOwNJ0SB                 32        57                      True
# R_poaCzravLe9WtQl                  5         0                      True
# R_rj41VGCbwbO1zHP                  4         0                      True
# R_sRwOfzbp6ufaWU9                  9         0                      True
# R_suiryM1wMLx8Prr                 13         0                      True
# R_ur0ff9OTvW0jB1D                  5         0                      True
# R_yvBX55C72Ye8W1b                102         2                      True
# R_zYlbzTtLmdvnpPb                 36         0                      True
# R_zfk080BHz6RWixb                163         6                      True
#
# [85 rows x 12 columns]
#                    Female  Male  Gender_Available  Majority  URM  \
# Class_ID
# R_12QFe4VQPh6oNW1       3     4              True         6    1
# R_12t10i0liTKxQuH      10    12              True        10   12
# R_1DA4MjYI6kJcpRW       2    14              True        15    1
# R_1E6g9AAGCZcNC4z       2     2              True         4    0
# R_1IB300CxBKh0Tw7      23    48              True        57   12
# R_1LHvn3R5Afj8eUc      48    34              True        62   18
# R_1Lv8h75V2mtHdj7       2    10              True        12    0
# R_1Oko8BpPfb9rt0G      14    70              True        76    7
# R_1PRvAep4UEZKmoi       1    12             False        10    3
# R_1QDH836nn3XsCEC       1     9             False         9    1
# R_1dHrngC5fnItWQj       1    10             False        11    0
# R_1eRcOhZpre7mhcC      10    14              True        19    4
# R_1gU9RGAQf2fpKPq       1     7             False         5    3
# R_1gubfNoIBBmw0wZ       5     9              True        14    0
# R_1ifcZfwB09mFFt0       1     2             False         3    0
# R_1ih5Iehl2ArglT2     102    89              True       145   43
# R_1jB7mHGYxH4Hgi8       2     7              True         9    1
# R_1n7wUeClpEuZOkp      12     0              True         7    7
# R_1nTRv0WikH05GGN       0     4              True         4    0
# R_1oBXVOVbXJ6mbd8       2     3              True         4    2
# R_1pJNmdyl9Z2lXit       4     9              True         6    7
# R_1reT6Pvd9hZsljf       5    12              True        10    7
# R_1riVAun30VkuYam       1     1             False         0    1
# R_22ufgL2VQq1l4Ft      53   142              True       171   20
# R_24q0K2G7CvLBC90       1     1             False         2    0
# R_27BAp1dY9KUURf1       3     4              True         6    0
# R_2DTys2sMNEPNUas      42    57              True        82   14
# R_2E3I53tWJ18Yrh1      12    22              True        29    3
# R_2R8MnTyv2jFgPzA      10    23              True        28    4
# R_2Sk1pkrUVnNsFyh       2     5              True         7    0
# ...                   ...   ...               ...       ...  ...
# R_2viXrWDhskmxswL       7     0              True         7    0
# R_2xOT2Y1NtNiseCk      28    38              True        56    9
# R_2zCk6102XCLdPVx       3    16              True        15    4
# R_3383bqp4hOSfVs6       2     4              True         7    0
# R_33C0JO3MvPhUjg0       0     1             False         0    1
# R_33svFR3Dzit5gMP      27    55              True        78    4
# R_3DvXkKcsXGosQmN       5     3              True         7    1
# R_3EfD4kQOcRIqPd1      33    34              True        62    5
# R_3FLrT3FNDbu41vG       0     4              True         3    1
# R_3Jx6pTC9zYp0JjN       0     3              True         3    0
# R_3KIXxDs5O6DnoMq      38   140              True       156   20
# R_3PFfsO3XVxfcdbo       8    21              True        27    2
# R_3QYRWvIUGTgTHLA      28    13              True        39    4
# R_3fNprNmbwV9C4X0      52    50              True        86   13
# R_3ijRcPfXo8MUfFj      97    83              True       149   27
# R_3kNzLJWZjV68mK7       2     6              True         7    1
# R_5vSHC3dAv5Rtvm9       0     4              True         2    2
# R_6VuzaPTgCFmgEmJ       2    12              True        13    2
# R_6rq9bCkfvLDJEdz      22    22              True        37    4
# R_AbnDTWVllhcHtN7      23     7              True        23    6
# R_DnPBuVnC0UjmC1b      10    22              True        25    7
# R_QaHsOagJRfOPuet       0     2              True         1    1
# R_RKRNIWFu1gZuSPf     164   108              True       189   78
# R_eDQgZq5IOwNJ0SB      24    51              True        72    5
# R_poaCzravLe9WtQl       3     2              True         2    3
# R_sRwOfzbp6ufaWU9       4     2              True         4    2
# R_ur0ff9OTvW0jB1D       2     3              True         4    1
# R_yvBX55C72Ye8W1b      34    57              True        84    6
# R_zYlbzTtLmdvnpPb      13     4              True        13    4
# R_zfk080BHz6RWixb      75    54              True       104   20
#
#                    URM_Available  Non-physics  Physics  Major_Available  \
# Class_ID
# R_12QFe4VQPh6oNW1          False            1        6            False
# R_12t10i0liTKxQuH           True           22        0             True
# R_1DA4MjYI6kJcpRW          False            0       16             True
# R_1E6g9AAGCZcNC4z           True            3        1            False
# R_1IB300CxBKh0Tw7           True           21       48             True
# R_1LHvn3R5Afj8eUc           True           81        1            False
# R_1Lv8h75V2mtHdj7           True            0       12             True
# R_1Oko8BpPfb9rt0G           True           26       55             True
# R_1PRvAep4UEZKmoi           True            1       12            False
# R_1QDH836nn3XsCEC          False            2        8             True
# R_1dHrngC5fnItWQj           True            0       11             True
# R_1eRcOhZpre7mhcC           True           24        0             True
# R_1gU9RGAQf2fpKPq           True            2        6             True
# R_1gubfNoIBBmw0wZ           True            0       14             True
# R_1ifcZfwB09mFFt0           True            3        0             True
# R_1ih5Iehl2ArglT2           True          183        9             True
# R_1jB7mHGYxH4Hgi8          False            0       10             True
# R_1n7wUeClpEuZOkp           True           11        2             True
# R_1nTRv0WikH05GGN           True            1        3            False
# R_1oBXVOVbXJ6mbd8           True            2        4             True
# R_1pJNmdyl9Z2lXit           True            4        9             True
# R_1reT6Pvd9hZsljf           True           10        7             True
# R_1riVAun30VkuYam          False            0        2             True
# R_22ufgL2VQq1l4Ft           True          191        2             True
# R_24q0K2G7CvLBC90           True            0        2             True
# R_27BAp1dY9KUURf1           True            6        1            False
# R_2DTys2sMNEPNUas           True           91        8             True
# R_2E3I53tWJ18Yrh1           True            0       34             True
# R_2R8MnTyv2jFgPzA           True           13       19             True
# R_2Sk1pkrUVnNsFyh           True            0        7             True
# ...                          ...          ...      ...              ...
# R_2viXrWDhskmxswL           True            0        7             True
# R_2xOT2Y1NtNiseCk           True           65        1            False
# R_2zCk6102XCLdPVx           True            0       19             True
# R_3383bqp4hOSfVs6           True            1        6            False
# R_33C0JO3MvPhUjg0          False            0        1            False
# R_33svFR3Dzit5gMP           True           77        5             True
# R_3DvXkKcsXGosQmN          False            5        3             True
# R_3EfD4kQOcRIqPd1           True           46       20             True
# R_3FLrT3FNDbu41vG          False            2        2             True
# R_3Jx6pTC9zYp0JjN           True            3        0             True
# R_3KIXxDs5O6DnoMq           True          172        1            False
# R_3PFfsO3XVxfcdbo           True            3       26             True
# R_3QYRWvIUGTgTHLA           True           41        2             True
# R_3fNprNmbwV9C4X0           True           89        8             True
# R_3ijRcPfXo8MUfFj           True          177        4             True
# R_3kNzLJWZjV68mK7          False            0        8             True
# R_5vSHC3dAv5Rtvm9           True            1        3            False
# R_6VuzaPTgCFmgEmJ           True            1       14            False
# R_6rq9bCkfvLDJEdz           True           30       10             True
# R_AbnDTWVllhcHtN7           True           30        0             True
# R_DnPBuVnC0UjmC1b           True           31        2             True
# R_QaHsOagJRfOPuet          False            0        2             True
# R_RKRNIWFu1gZuSPf           True          260       10             True
# R_eDQgZq5IOwNJ0SB           True           74        2             True
# R_poaCzravLe9WtQl           True            0        5             True
# R_sRwOfzbp6ufaWU9           True            6        0             True
# R_ur0ff9OTvW0jB1D          False            0        5             True
# R_yvBX55C72Ye8W1b           True           86        5             True
# R_zYlbzTtLmdvnpPb           True           17        0             True
# R_zfk080BHz6RWixb           True          125        2             True
#
#                    Beyond-first-year  Freshman  Class_Standing_Available
# Class_ID
# R_12QFe4VQPh6oNW1                  6         1                     False
# R_12t10i0liTKxQuH                 22         0                      True
# R_1DA4MjYI6kJcpRW                 16         0                      True
# R_1E6g9AAGCZcNC4z                  0         4                      True
# R_1IB300CxBKh0Tw7                  3        69                      True
# R_1LHvn3R5Afj8eUc                  5        77                      True
# R_1Lv8h75V2mtHdj7                 12         0                      True
# R_1Oko8BpPfb9rt0G                  2        82                      True
# R_1PRvAep4UEZKmoi                 13         0                      True
# R_1QDH836nn3XsCEC                 10         0                      True
# R_1dHrngC5fnItWQj                 10         1                     False
# R_1eRcOhZpre7mhcC                 20         4                      True
# R_1gU9RGAQf2fpKPq                  8         0                      True
# R_1gubfNoIBBmw0wZ                 14         0                      True
# R_1ifcZfwB09mFFt0                  1         2                     False
# R_1ih5Iehl2ArglT2                171        22                      True
# R_1jB7mHGYxH4Hgi8                 10         0                      True
# R_1n7wUeClpEuZOkp                 14         0                      True
# R_1nTRv0WikH05GGN                  4         0                      True
# R_1oBXVOVbXJ6mbd8                  1         5                     False
# R_1pJNmdyl9Z2lXit                 13         0                      True
# R_1reT6Pvd9hZsljf                 13         4                      True
# R_1riVAun30VkuYam                  2         0                      True
# R_22ufgL2VQq1l4Ft                196         0                      True
# R_24q0K2G7CvLBC90                  2         0                      True
# R_27BAp1dY9KUURf1                  7         0                      True
# R_2DTys2sMNEPNUas                 98         1                     False
# R_2E3I53tWJ18Yrh1                 34         0                      True
# R_2R8MnTyv2jFgPzA                  1        32                     False
# R_2Sk1pkrUVnNsFyh                  7         0                      True
# ...                              ...       ...                       ...
# R_2viXrWDhskmxswL                  7         0                      True
# R_2xOT2Y1NtNiseCk                  6        60                      True
# R_2zCk6102XCLdPVx                 19         0                      True
# R_3383bqp4hOSfVs6                  7         0                      True
# R_33C0JO3MvPhUjg0                  1         0                     False
# R_33svFR3Dzit5gMP                 21        61                      True
# R_3DvXkKcsXGosQmN                  8         0                      True
# R_3EfD4kQOcRIqPd1                 49        18                      True
# R_3FLrT3FNDbu41vG                  4         0                      True
# R_3Jx6pTC9zYp0JjN                  3         0                      True
# R_3KIXxDs5O6DnoMq                176         3                      True
# R_3PFfsO3XVxfcdbo                 28         1                     False
# R_3QYRWvIUGTgTHLA                 42         1                     False
# R_3fNprNmbwV9C4X0                 49        53                      True
# R_3ijRcPfXo8MUfFj                 46       136                      True
# R_3kNzLJWZjV68mK7                  7         0                      True
# R_5vSHC3dAv5Rtvm9                  1         3                     False
# R_6VuzaPTgCFmgEmJ                 15         0                      True
# R_6rq9bCkfvLDJEdz                  1        45                     False
# R_AbnDTWVllhcHtN7                 30         0                      True
# R_DnPBuVnC0UjmC1b                  5        28                      True
# R_QaHsOagJRfOPuet                  2         0                      True
# R_RKRNIWFu1gZuSPf                 11       266                      True
# R_eDQgZq5IOwNJ0SB                 28        49                      True
# R_poaCzravLe9WtQl                  5         0                      True
# R_sRwOfzbp6ufaWU9                  6         0                      True
# R_ur0ff9OTvW0jB1D                  5         0                      True
# R_yvBX55C72Ye8W1b                 89         2                      True
# R_zYlbzTtLmdvnpPb                 17         0                      True
# R_zfk080BHz6RWixb                125         4                      True
#
# [69 rows x 12 columns]

# %%
df_Final.to_csv('Collective_Surveys/Complete/Complete_Concat_DeIdentified.csv', index = False)
